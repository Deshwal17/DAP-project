# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
ev=pd.read_csv('ENV_IND_F.csv')
ev.head()
# Out:
#    year country_code    indicator_id                          indicator_name  \
# 0  2020          ABW  EN.ATM.CO2E.PC  CO2 emissions (metric tons per capita)
# 1  2019          ABW  EN.ATM.CO2E.PC  CO2 emissions (metric tons per capita)
# 2  2018          ABW  EN.ATM.CO2E.PC  CO2 emissions (metric tons per capita)
# 3  2017          ABW  EN.ATM.CO2E.PC  CO2 emissions (metric tons per capita)
# 4  2016          ABW  EN.ATM.CO2E.PC  CO2 emissions (metric tons per capita)
#
#    value
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
sns.lmplot(x='year',y='value',data=ev,fit_reg=False,hue='indicator_name',scatter_kws={"s": 1})
# Out:
# <img src="data:image/png;base64,..." width="1853">

# %%
ev[['value','indicator_name']].groupby(by=['indicator_name']).sum()
# Out:
#                                                            value
# indicator_name
# CO2 emissions (kt)                                  1.014140e+10
# CO2 emissions (metric tons per capita)              4.746106e+04
# Forest area (% of land area)                        2.607143e+05
# Mean Global Temperature                             4.348458e+05
# Methane emissions (kt of CO2 equivalent)            3.327834e+09
# Total greenhouse gas emissions (kt of CO2 equiv...  1.564367e+10

# %%
sns.stripplot(ev['indicator_name'],ev['year'])
# Out:
# /Users/himanshudeshwal/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='indicator_name', ylabel='year'>

# %%
sns.pairplot(ev[['value','year']])
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.lmplot(x='year',y='value',data=ev,scatter_kws={"s": 1})
# Out:
# <img src="data:image/png;base64,..." width="500">
